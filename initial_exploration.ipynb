# %%
import pandas as pd

# %%
temp = pd.read_csv("./data/raw/usage-stats/321JourneyDataExtract08Jun2022-14Jun2022.csv")

# %%
temp
# Out:
#         Rental Id  Duration  Bike Id          End Date  EndStation Id  \
# 0       121106358       600     1568  08/06/2022 18:25            255
# 1       121302606       300     1521  13/06/2022 12:16            176
# 2       121174940       900    19809  10/06/2022 13:46             56
# 3       121113183       360    19499  08/06/2022 20:18             36
# 4       121339587       480    10647  14/06/2022 08:58            228
# ...           ...       ...      ...               ...            ...
# 293620  121337003      1380    22616  14/06/2022 08:42            320
# 293621  121376741      1260    18150  14/06/2022 23:06            156
# 293622  121098329      1500    22333  08/06/2022 16:38            330
# 293623  121345863      4080    16059  14/06/2022 13:00            482
# 293624  121283080      1200    12858  12/06/2022 19:48            288
#
#                                     EndStation Name        Start Date  \
# ...

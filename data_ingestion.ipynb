# %%
import pandas as pd
import os
from pathlib import Path

# %%
# Out:
# 'c:\\dev\\tfl_santander_cycles'

# %%
CWD_DIR = os.getcwd()
DATA_DIR = os.path.join(CWD_DIR, "data\\raw")
USAGE_DIR = os.path.join(DATA_DIR, "usage-stats")

# %%
temp = pd.read_csv(os.path.join(USAGE_DIR, "321JourneyDataExtract08Jun2022-14Jun2022.csv"))

# %%
target_dir = Path(USAGE_DIR)

csv_names = [file.name for file in target_dir.iterdir() if file.suffix == ".csv"]

# %%
# Out:
# <bound method Path.iterdir of WindowsPath('c:/dev/tfl_santander_cycles/data/raw/usage-stats')>
